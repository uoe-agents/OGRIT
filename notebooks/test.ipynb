# %%
from core.feature_extraction import FeatureExtractor, GoalDetector
from core.data_processing import get_multi_scenario_dataset

# %%
scenarios = ['heckstrasse', 'bendplatz', 'frankenberg']
dataset = get_multi_scenario_dataset(scenarios, 'train')

# %%
dataset
# Out:
#       path_to_goal_length  in_correct_lane      speed  acceleration  \
# 0               41.611327             True  11.170532      1.760858
# 1               31.241883            False  11.170532      1.760858
# 2               41.164066             True  11.264291      1.758835
# 3               30.794623            False  11.264291      1.758835
# 4               40.709242             True  11.356770      1.733866
# ...                   ...              ...        ...           ...
# 5742            16.790834             True   2.793110      1.053911
# 5743             9.958441             True   2.793110      1.053911
# 5744             7.592125             True   2.793110      1.053911
# 5745             6.813694             True   3.579086      1.688182
# 5746             2.804431             True   3.579086      1.688182
#
#       angle_in_lane  vehicle_in_front_dist  vehicle_in_front_speed  \
# 0         -0.009510              28.468039               12.818461
# ...

# %%
dataset.goal_type.unique()
# Out:
# array(['straight-on', 'turn-left', 'turn-right'], dtype=object)
