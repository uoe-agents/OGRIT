# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from igp2 import AgentState
from igp2.data.data_loaders import InDDataLoader
from igp2.data.episode import Frame
from igp2.data.scenario import InDScenario, ScenarioConfig
from igp2.opendrive.map import Map
from igp2.opendrive.plot_map import plot_map
from grit.core.data_processing import get_dataset

# %%
test_set = get_dataset('round', 'test')

# %%
test_set.true_goal.value_counts() / test_set.true_goal.shape[0]
# Out:
# 0    0.386155
# 2    0.265927
# 1    0.180200
# 3    0.167718
# Name: true_goal, dtype: float64

# %%
test_set
# Out:
#        path_to_goal_length  in_correct_lane     speed  acceleration  \
# 0                37.668293             True  4.425219      1.237664
# 1                69.035355             True  4.425219      1.237664
# 2               109.806009             True  4.425219      1.237664
# 3               139.102393             True  4.425219      1.237664
# 4                32.565355             True  5.144091      0.869355
# ...                    ...              ...       ...           ...
# 76543            96.844461             True  6.505979      1.483180
# 76544           130.278941             True  7.123876      0.505092
# 76545            19.631292             True  7.123876      0.505092
# 76546            60.401946             True  7.123876      0.505092
# 76547            89.698330             True  7.123876      0.505092
#
#        angle_in_lane  vehicle_in_front_dist  vehicle_in_front_speed  \
# 0          -0.235979             100.000000               20.000000
# 1          -0.235979             100.000000               20.000000
# 2          -0.235979              78.646403                6.118256
# 3          -0.235979              78.646403                6.118256
# 4          -0.174028              21.533931                7.689521
# ...              ...                    ...                     ...
# 76543      -0.256828              84.817137                8.830591
# 76544       0.454194              46.357458               10.425151
# 76545       0.454194             100.000000               20.000000
# 76546       0.454194              46.107603               10.425151
# 76547       0.454194              46.357458               10.425151
#
#        oncoming_vehicle_dist  oncoming_vehicle_speed  road_heading  ...  \
# 0                      100.0                    20.0     -0.852636  ...
# 1                      100.0                    20.0     -0.865193  ...
# 2                      100.0                    20.0     -0.823158  ...
# 3                      100.0                    20.0     -0.740689  ...
# 4                      100.0                    20.0     -0.852636  ...
# ...                      ...                     ...           ...  ...
# 76543                  100.0                    20.0     -0.740689  ...
# 76544                  100.0                    20.0     -0.852636  ...
# 76545                  100.0                    20.0     -0.865193  ...
# 76546                  100.0                    20.0     -0.823158  ...
# 76547                  100.0                    20.0     -0.740689  ...
#
#        agent_id ego_agent_id  possible_goal  true_goal   true_goal_type  \
# 0            12           13              0          2  exit-roundabout
# 1            12           13              1          2  exit-roundabout
# 2            12           13              2          2  exit-roundabout
# 3            12           13              3          2  exit-roundabout
# 4            12           13              0          2  exit-roundabout
# ...         ...          ...            ...        ...              ...
# 76543       459          453              3          2  exit-roundabout
# 76544       459          453              0          2  exit-roundabout
# 76545       459          453              1          2  exit-roundabout
# 76546       459          453              2          2  exit-roundabout
# 76547       459          453              3          2  exit-roundabout
#
#        frame_id  initial_frame_id  fraction_observed  final_frame_id episode
# 0             0                 0           0.000000           360.0       4
# 1             0                 0           0.000000           360.0       4
# 2             0                 0           0.000000           360.0       4
# 3             0                 0           0.000000           360.0       4
# 4            25                 0           0.069444           360.0       4
# ...         ...               ...                ...             ...     ...
# 76543     23450             23365           0.361702         23600.0      21
# 76544     23475             23365           0.468085         23600.0      21
# 76545     23475             23365           0.468085         23600.0      21
# 76546     23475             23365           0.468085         23600.0      21
# 76547     23475             23365           0.468085         23600.0      21
#
# [185239 rows x 25 columns]

# %%
results_simple = pd.read_csv('../../predictions/round_occlusion_baseline_test.csv')

# %%
results_privileged = pd.read_csv('../../predictions/round_generalised_grit_test.csv')

# %%
results_simple
# Out:
#        episode  agent_id  ego_agent_id  frame_id  true_goal   true_goal_type  \
# 0            4        12            13         0          2  exit-roundabout
# 1            4        12            13        25          2  exit-roundabout
# 2            4        12            13        50          2  exit-roundabout
# 3            4        12            13        75          2  exit-roundabout
# 4            4        12            13       100          2  exit-roundabout
# ...        ...       ...           ...       ...        ...              ...
# 46305       21       459           453     23375          2  exit-roundabout
# 46306       21       459           453     23400          2  exit-roundabout
# 46307       21       459           453     23425          2  exit-roundabout
# 46308       21       459           453     23450          2  exit-roundabout
# 46309       21       459           453     23475          2  exit-roundabout
#
#        fraction_observed  model_prediction predicted_goal_type  model_probs  \
# 0               0.000000                 1     exit-roundabout     0.592404
# 1               0.069444                 1     exit-roundabout     0.592404
# 2               0.138889                 1     exit-roundabout     0.592404
# 3               0.208333                 1     exit-roundabout     0.671037
# 4               0.277778                 1     exit-roundabout     0.671037
# ...                  ...               ...                 ...          ...
# 46305           0.042553                 2     exit-roundabout     0.830856
# 46306           0.148936                 2     exit-roundabout     0.830856
# 46307           0.255319                 2     exit-roundabout     0.826431
# 46308           0.361702                 2     exit-roundabout     0.830856
# 46309           0.468085                 2     exit-roundabout     0.826431
#
#        max_probs  min_probs  model_entropy  model_entropy_norm  \
# 0       0.592404   0.003045       0.724666            0.522736
# 1       0.592404   0.003045       0.724666            0.522736
# 2       0.592404   0.003045       0.724666            0.522736
# 3       0.671037   0.003896       0.692523            0.499549
# 4       0.671037   0.003896       0.692523            0.499549
# ...          ...        ...            ...                 ...
# 46305   0.830856   0.007683       0.519074            0.374433
# 46306   0.830856   0.007683       0.519074            0.374433
# 46307   0.826431   0.007642       0.540311            0.389752
# 46308   0.830856   0.007683       0.519074            0.374433
# 46309   0.826431   0.007642       0.540311            0.389752
#
#        true_goal_prob  cross_entropy  model_correct
# 0            0.398663       0.229910          False
# 1            0.398663       0.229910          False
# 2            0.398663       0.229910          False
# 3            0.316961       0.287244          False
# 4            0.316961       0.287244          False
# ...               ...            ...            ...
# 46305        0.830856       0.046325           True
# 46306        0.830856       0.046325           True
# 46307        0.826431       0.047660           True
# 46308        0.830856       0.046325           True
# 46309        0.826431       0.047660           True
#
# [46310 rows x 17 columns]

# %%
results_privileged
# Out:
#        episode  agent_id  ego_agent_id  frame_id  true_goal   true_goal_type  \
# 0            4        12            13         0          2  exit-roundabout
# 1            4        12            13        25          2  exit-roundabout
# 2            4        12            13        50          2  exit-roundabout
# 3            4        12            13        75          2  exit-roundabout
# 4            4        12            13       100          2  exit-roundabout
# ...        ...       ...           ...       ...        ...              ...
# 46305       21       459           453     23375          2  exit-roundabout
# 46306       21       459           453     23400          2  exit-roundabout
# 46307       21       459           453     23425          2  exit-roundabout
# 46308       21       459           453     23450          2  exit-roundabout
# 46309       21       459           453     23475          2  exit-roundabout
#
#        fraction_observed  model_prediction predicted_goal_type  model_probs  \
# 0               0.000000                 1     exit-roundabout     0.592404
# 1               0.069444                 1     exit-roundabout     0.592404
# 2               0.138889                 1     exit-roundabout     0.592404
# 3               0.208333                 1     exit-roundabout     0.671037
# 4               0.277778                 1     exit-roundabout     0.671037
# ...                  ...               ...                 ...          ...
# 46305           0.042553                 2     exit-roundabout     0.826431
# 46306           0.148936                 2     exit-roundabout     0.826431
# 46307           0.255319                 2     exit-roundabout     0.826431
# 46308           0.361702                 2     exit-roundabout     0.826431
# 46309           0.468085                 2     exit-roundabout     0.826431
#
#        max_probs  min_probs  model_entropy  model_entropy_norm  \
# 0       0.592404   0.003045       0.724666            0.522736
# 1       0.592404   0.003045       0.724666            0.522736
# 2       0.592404   0.003045       0.724666            0.522736
# 3       0.671037   0.003896       0.692523            0.499549
# 4       0.671037   0.003896       0.692523            0.499549
# ...          ...        ...            ...                 ...
# 46305   0.826431   0.007642       0.540311            0.389752
# 46306   0.826431   0.007642       0.540311            0.389752
# 46307   0.826431   0.007642       0.540311            0.389752
# 46308   0.826431   0.007642       0.540311            0.389752
# 46309   0.826431   0.007642       0.540311            0.389752
#
#        true_goal_prob  cross_entropy  model_correct
# 0            0.398663       0.229910          False
# 1            0.398663       0.229910          False
# 2            0.398663       0.229910          False
# 3            0.316961       0.287244          False
# 4            0.316961       0.287244          False
# ...               ...            ...            ...
# 46305        0.826431       0.047660           True
# 46306        0.826431       0.047660           True
# 46307        0.826431       0.047660           True
# 46308        0.826431       0.047660           True
# 46309        0.826431       0.047660           True
#
# [46310 rows x 17 columns]

# %%
cols = ['episode', 'agent_id', 'ego_agent_id', 'frame_id', 'model_correct', 'true_goal_prob', 'model_prediction']
results_merged = results_simple[cols].merge(results_privileged[cols], on=['episode', 'agent_id', 'ego_agent_id', 'frame_id'])

# %%
dataset_merged = results_merged.merge(test_set, on=['episode', 'agent_id', 'ego_agent_id', 'frame_id'])

# %%
dataset_merged
# Out:
#         episode  agent_id  ego_agent_id  frame_id  model_correct_x  \
# 0             4        12            13         0            False
# 1             4        12            13         0            False
# 2             4        12            13         0            False
# 3             4        12            13         0            False
# 4             4        12            13        25            False
# ...         ...       ...           ...       ...              ...
# 185234       21       459           453     23450             True
# 185235       21       459           453     23475             True
# 185236       21       459           453     23475             True
# 185237       21       459           453     23475             True
# 185238       21       459           453     23475             True
#
#         true_goal_prob_x  model_prediction_x  model_correct_y  \
# 0               0.398663                   1            False
# 1               0.398663                   1            False
# 2               0.398663                   1            False
# 3               0.398663                   1            False
# 4               0.398663                   1            False
# ...                  ...                 ...              ...
# 185234          0.830856                   2             True
# 185235          0.826431                   2             True
# 185236          0.826431                   2             True
# 185237          0.826431                   2             True
# 185238          0.826431                   2             True
#
#         true_goal_prob_y  model_prediction_y  ...        goal_type  \
# 0               0.398663                   1  ...  exit-roundabout
# 1               0.398663                   1  ...  exit-roundabout
# 2               0.398663                   1  ...  exit-roundabout
# 3               0.398663                   1  ...  exit-roundabout
# 4               0.398663                   1  ...  exit-roundabout
# ...                  ...                 ...  ...              ...
# 185234          0.826431                   2  ...  exit-roundabout
# 185235          0.826431                   2  ...  exit-roundabout
# 185236          0.826431                   2  ...  exit-roundabout
# 185237          0.826431                   2  ...  exit-roundabout
# 185238          0.826431                   2  ...  exit-roundabout
#
#         vehicle_in_front_missing  oncoming_vehicle_missing  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 185234                      True                      True
# 185235                     False                     False
# 185236                     False                      True
# 185237                     False                     False
# 185238                     False                     False
#
#         exit_number_missing  possible_goal  true_goal   true_goal_type  \
# 0                     False              0          2  exit-roundabout
# 1                     False              1          2  exit-roundabout
# 2                     False              2          2  exit-roundabout
# 3                     False              3          2  exit-roundabout
# 4                     False              0          2  exit-roundabout
# ...                     ...            ...        ...              ...
# 185234                False              3          2  exit-roundabout
# 185235                False              0          2  exit-roundabout
# 185236                False              1          2  exit-roundabout
# 185237                False              2          2  exit-roundabout
# 185238                False              3          2  exit-roundabout
#
#         initial_frame_id  fraction_observed  final_frame_id
# 0                      0           0.000000           360.0
# 1                      0           0.000000           360.0
# 2                      0           0.000000           360.0
# 3                      0           0.000000           360.0
# 4                      0           0.069444           360.0
# ...                  ...                ...             ...
# 185234             23365           0.361702         23600.0
# 185235             23365           0.468085         23600.0
# 185236             23365           0.468085         23600.0
# 185237             23365           0.468085         23600.0
# 185238             23365           0.468085         23600.0
#
# [185239 rows x 31 columns]

# %%
descrepancies = dataset_merged.loc[(dataset_merged.true_goal_prob_y - dataset_merged.true_goal_prob_x) > 0.1]

# %%
descrepancies.sample(10)
# Out:
#         episode  agent_id  ego_agent_id  frame_id  model_correct_x  \
# 107165        4       755           759     30875             True
# 154511       21       260           263     13675             True
# 30497         4       290           292     12325            False
# 175058       21       392           401     20000            False
# 30470         4       290           292     12150            False
# 96435         4       698           703     28950            False
# 183645       21       446           453     23225            False
# 119781       21       112           115      5825            False
# 52633         4       399           401     16325            False
# 181482       21       439           443     23000            False
#
#         true_goal_prob_x  model_prediction_x  model_correct_y  \
# 107165              0.25                   0             True
# 154511              0.25                   0             True
# 30497               0.25                   0             True
# 175058              0.25                   0             True
# 30470               0.25                   0            False
# 96435               0.25                   0             True
# 183645              0.25                   0             True
# 119781              0.25                   0             True
# 52633               0.25                   0             True
# 181482              0.25                   0             True
#
#         true_goal_prob_y  model_prediction_y  ...        goal_type  \
# 107165          0.675366                   0  ...  exit-roundabout
# 154511          0.930993                   0  ...  exit-roundabout
# 30497           0.871162                   1  ...  exit-roundabout
# 175058          0.542431                   1  ...  exit-roundabout
# 30470           0.352229                   0  ...  exit-roundabout
# 96435           0.874669                   2  ...  exit-roundabout
# 183645          0.873861                   1  ...  exit-roundabout
# 119781          0.708349                   2  ...  exit-roundabout
# 52633           0.684062                   3  ...  exit-roundabout
# 181482          0.930993                   2  ...  exit-roundabout
#
#         vehicle_in_front_missing  oncoming_vehicle_missing  \
# 107165                      True                     False
# 154511                      True                     False
# 30497                       True                     False
# 175058                     False                     False
# 30470                       True                     False
# 96435                      False                     False
# 183645                     False                      True
# 119781                     False                     False
# 52633                      False                     False
# 181482                      True                      True
#
#         exit_number_missing  possible_goal  true_goal   true_goal_type  \
# 107165                 True              2          0  exit-roundabout
# 154511                 True              0          0  exit-roundabout
# 30497                  True              2          1  exit-roundabout
# 175058                 True              3          1  exit-roundabout
# 30470                  True              3          1  exit-roundabout
# 96435                  True              0          2  exit-roundabout
# 183645                 True              2          1  exit-roundabout
# 119781                 True              2          2  exit-roundabout
# 52633                  True              2          3  exit-roundabout
# 181482                 True              3          2  exit-roundabout
#
#         initial_frame_id  fraction_observed  final_frame_id
# 107165             30655           0.687500         30975.0
# 154511             13141           1.000000         13675.0
# 30497              11962           0.930769         12352.0
# 175058             19796           0.784615         20056.0
# 30470              11962           0.482051         12352.0
# 96435              28637           0.978125         28957.0
# 183645             22972           0.937037         23242.0
# 119781              5718           0.516908          5925.0
# 52633              16142           1.000000         16325.0
# 181482             22719           1.000000         23000.0
#
# [10 rows x 31 columns]
