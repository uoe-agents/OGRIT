# %%
from grit.core.feature_extraction import FeatureExtractor, GoalDetector
from grit.core.data_processing import get_multi_scenario_dataset
from igp2 import Map, plot_map

# %%
scenario_name = 'round'
scenario_map = Map.parse_from_opendrive(f"../../scenarios/maps/{scenario_name}.xodr")

# %%
plot_map(scenario_map)
# Out:
# <AxesSubplot:>

# %%
scenario_map.lanes_at((59.8, -32.8))
# Out:
# [Lane(id=-1) on Road(id=11)]

# %%
ax = plot_map(scenario_map)
lane = scenario_map.get_lane(26, -1)
ax.plot(*list(zip(*[x for x in lane.midline.coords])))

# %%
ax = plot_map(scenario_map)
lane = scenario_map.get_lane(1, 2)
ax.plot(*list(zip(*[x for x in lane.midline.coords])))

# %%
inti
